# %%
import pandas as pd
import numpy as np
import re
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("ld.csv")
df.head()
# Out:
#                                                 Text Language
# 0   Nature, in the broadest sense, is the natural...  English
# 1  "Nature" can refer to the phenomena of the phy...  English
# 2  The study of nature is a large, if not the onl...  English
# 3  Although humans are part of nature, human acti...  English
# 4  [1] The word nature is borrowed from the Old F...  English

# %%
df.shape
# Out:
# (10337, 2)

# %%
df["Language"].value_counts()
# Out:
# Language
# English       1385
# French        1014
# Spanish        819
# Portugeese     739
# Italian        698
# Russian        692
# Sweedish       676
# Malayalam      594
# Dutch          546
# Arabic         536
# Turkish        474
# German         470
# Tamil          469
# Danish         428
# Kannada        369
# Greek          365
# Hindi           63
# Name: count, dtype: int64

# %%
le=LabelEncoder()
df["Language"]=le.fit_transform(df["Language"])
df.head()
# Out:
#                                                 Text  Language
# 0   Nature, in the broadest sense, is the natural...         3
# 1  "Nature" can refer to the phenomena of the phy...         3
# 2  The study of nature is a large, if not the onl...         3
# 3  Although humans are part of nature, human acti...         3
# 4  [1] The word nature is borrowed from the Old F...         3

# %%
df[df["Language"]==6]
# Out:
#                                                    Text  Language
# 5629  Δεν υπάρχει αυτή τη στιγμή  λήμμα με αυτόν τον...         6
# 5630  Αν περιμένατε να βρίσκεται εδώ μια σελίδα και ...         6
# 5631  (Δείτε την γρήγορη διαγραφή σελίδων για πιθανο...         6
# 5632  Μπορείτε να δοκιμάστε την λειτουργία εκκαθάρισ...         6
# 5633  Η Βικιπαίδεια (αγγλικά: Wikipedia, γουικιπίντι...         6
# ...                                                 ...       ...
# 5989  τι ήρθε το λάθος σου, ας σου δώσουμε κάτι ωραί...         6
# 5990  Η ναρκίσσα άλλαξε τους τρόπους της που αγωνίστ...         6
# 5991  πως' Ο ναρκισσισμός, τώρα η Μαρία, τους είπε ό...         6
# 5992  Μήπως υποθέτω ότι δεν θα ήθελε άλλο χρυσό ψωμί...         6
# 5993  Terry, στην πραγματικότητα μοιάζεις λίγο με αυ...         6
#
# [365 rows x 2 columns]

# %%
x=df["Text"]
y=df["Language"]

# %%
data_list=[]
for text in x:
    text=re.sub('[!@#$(),n"%*?:;~`0-9]'," ",text)
    text=text.lower()
    data_list.append(text)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv=CountVectorizer()
x=cv.fit_transform(data_list).toarray()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
model=MultinomialNB()
model.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([12,  8,  3, ...,  2,  6,  4])

# %%
def predict(text):
    x=cv.transform([text]).toarray()
    lang=model.predict(x)
    print(lang)
    lang=le.inverse_transform(lang)
    print(lang)
    print("The Language is in",lang[0])

# %%
predict("Hello and welcome dosto")
# Out:
# [3]
# ['English']
# The Language is in English

# %%
predict("ನಾರ್ಸಿಸಾ ತಾನು ಮೊದಲಿಗೆ")
# Out:
# [9]
# ['Kannada']
# The Language is in Kannada

# %%
import pickle

# %%
pickle.dump(model,open("ldmodel.pkl","wb"))
pickle.dump(cv,open("ldvector.pkl","wb"))
